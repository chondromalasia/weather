# %% [markdown]
# # Let's start some basic analytics

# %%
import sys

import sqlite3
from collections import Counter

import pandas as pd

sys.path.append("..")

import src.utils as utils
import src.scraper as sc

# %%
db_path = utils.root_path / "data" / "data.db"
db_path.exists()
# Out:
# True

# %%
conn = sqlite3.connect(str(db_path))

# %%
query = """SELECT forecasts.CITY, 
        date(FORECAST_DATE) as forecast_date, 
        PLATFORM, 
        forecasts.TEMPERATURE as forecast_temperature,
        date(DATE) as observed_date,
        observed_temp.TEMPERATURE as observed_temperature
 FROM forecasts
LEFT JOIN observed_temp
ON forecasts.city = observed_temp.city
AND date(forecasts.forecast_date) = date(observed_temp.date);
"""

# %%
df = pd.read_sql_query(query, conn)
conn.close()
df
# Out:
#     CITY forecast_date     PLATFORM  forecast_temperature observed_date  \
# 0    CHI    2022-11-05          TWC                    65    2022-11-05
# 1    NYC    2022-11-05          TWC                    73    2022-11-05
# 2    NYC    2022-11-05  Accuweather                    73    2022-11-05
# 3    CHI    2022-11-05  Accuweather                    63    2022-11-05
# 4    NYC    2022-11-05          NWS                    72    2022-11-05
# ..   ...           ...          ...                   ...           ...
# 344  CHI    2022-12-09  Accuweather                    40          None
# 345  NYC    2022-12-09          NWS                    46          None
# 346  CHI    2022-12-09          NWS                    39          None
# 347  NYC    2022-12-09       foreca                    46          None
# 348  CHI    2022-12-09       foreca                    39          None
#
#      observed_temperature
# 0                    71.0
# 1                    76.0
# 2                    76.0
# 3                    71.0
# 4                    76.0
# ..                    ...
# 344                   NaN
# 345                   NaN
# 346                   NaN
# 347                   NaN
# 348                   NaN
#
# [349 rows x 6 columns]

# %%
df = df.dropna(subset=['observed_temperature', "forecast_temperature"])
df
# Out:
#     CITY forecast_date     PLATFORM  forecast_temperature observed_date  \
# 0    CHI    2022-11-05          TWC                    65    2022-11-05
# 1    NYC    2022-11-05          TWC                    73    2022-11-05
# 2    NYC    2022-11-05  Accuweather                    73    2022-11-05
# 3    CHI    2022-11-05  Accuweather                    63    2022-11-05
# 4    NYC    2022-11-05          NWS                    72    2022-11-05
# ..   ...           ...          ...                   ...           ...
# 328  CHI    2022-12-07  Accuweather                    46    2022-12-07
# 329  NYC    2022-12-07          NWS                    57    2022-12-07
# 330  CHI    2022-12-07          NWS                    45    2022-12-07
# 331  NYC    2022-12-07       foreca                    57    2022-12-07
# 332  CHI    2022-12-07       foreca                    46    2022-12-07
#
#      observed_temperature
# 0                    71.0
# 1                    76.0
# 2                    76.0
# 3                    71.0
# 4                    76.0
# ..                    ...
# 328                  43.0
# 329                  59.0
# 330                  43.0
# 331                  59.0
# 332                  43.0
#
# [301 rows x 6 columns]

# %%
# this should be nothing, but it's worth a check
df[df["forecast_temperature"] == '']
# Out:
# Empty DataFrame
# Columns: [CITY, forecast_date, PLATFORM, forecast_temperature, observed_date, observed_temperature]
# Index: []

# %%
df["observed_temperature"] = df["observed_temperature"].astype(int)
df["forecast_temperature"] = df["forecast_temperature"].astype(int)
df
# Out:
# /tmp/ipykernel_16758/2382561297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["observed_temperature"] = df["observed_temperature"].astype(int)
# /tmp/ipykernel_16758/2382561297.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["forecast_temperature"] = df["forecast_temperature"].astype(int)
#     CITY forecast_date     PLATFORM  forecast_temperature observed_date  \
# 0    CHI    2022-11-05          TWC                    65    2022-11-05
# 1    NYC    2022-11-05          TWC                    73    2022-11-05
# 2    NYC    2022-11-05  Accuweather                    73    2022-11-05
# 3    CHI    2022-11-05  Accuweather                    63    2022-11-05
# 4    NYC    2022-11-05          NWS                    72    2022-11-05
# ..   ...           ...          ...                   ...           ...
# 328  CHI    2022-12-07  Accuweather                    46    2022-12-07
# 329  NYC    2022-12-07          NWS                    57    2022-12-07
# 330  CHI    2022-12-07          NWS                    45    2022-12-07
# 331  NYC    2022-12-07       foreca                    57    2022-12-07
# 332  CHI    2022-12-07       foreca                    46    2022-12-07
#
#      observed_temperature
# 0                      71
# 1                      76
# 2                      76
# 3                      71
# 4                      76
# ..                    ...
# 328                    43
# 329                    59
# 330                    43
# 331                    59
# 332                    43
#
# [301 rows x 6 columns]

# %%
df["error"] = df["observed_temperature"] -  df["forecast_temperature"] 
df
# Out:
# /tmp/ipykernel_16758/3409431157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["error"] = df["observed_temperature"] -  df["forecast_temperature"]
#     CITY forecast_date     PLATFORM  forecast_temperature observed_date  \
# 0    CHI    2022-11-05          TWC                    65    2022-11-05
# 1    NYC    2022-11-05          TWC                    73    2022-11-05
# 2    NYC    2022-11-05  Accuweather                    73    2022-11-05
# 3    CHI    2022-11-05  Accuweather                    63    2022-11-05
# 4    NYC    2022-11-05          NWS                    72    2022-11-05
# ..   ...           ...          ...                   ...           ...
# 328  CHI    2022-12-07  Accuweather                    46    2022-12-07
# 329  NYC    2022-12-07          NWS                    57    2022-12-07
# 330  CHI    2022-12-07          NWS                    45    2022-12-07
# 331  NYC    2022-12-07       foreca                    57    2022-12-07
# 332  CHI    2022-12-07       foreca                    46    2022-12-07
#
#      observed_temperature  error
# 0                      71      6
# 1                      76      3
# 2                      76      3
# 3                      71      8
# 4                      76      4
# ..                    ...    ...
# 328                    43     -3
# 329                    59      2
# 330                    43     -2
# 331                    59      2
# 332                    43     -3
#
# [301 rows x 7 columns]

# %%
df_chi = df[df["CITY"]=='CHI']

# %%
errors = df_chi[["PLATFORM", "error"]].groupby('PLATFORM')["error"].value_counts()
errors
# Out:
# PLATFORM     error
# Accuweather   0       8
#               2       6
#               1       4
#              -3       3
#              -1       3
#               4       3
#              -4       2
#               3       2
#               8       2
#               5       1
#               6       1
#               9       1
#               13      1
#               19      1
# NWS           4       7
#               3       6
#               1       5
#               0       4
#              -2       3
#               2       3
#              -1       2
#               5       2
#               9       2
#               10      2
#               13      1
#               21      1
# TWC           1       8
#               0       7
#              -1       5
#               2       3
#               3       3
#              -3       2
#              -2       2
#              -5       1
#               4       1
#               5       1
#               6       1
#               7       1
#               8       1
#               12      1
#               21      1
# foreca        0       8
#               2       5
#               4       5
#               3       4
#              -3       3
#              -1       3
#               1       2
#               5       2
#               8       1
#               9       1
#               10      1
#               14      1
# Name: error, dtype: int64

# %%
accu_error = errors["Accuweather"]
accu_error
# Out:
# error
#  0     8
#  2     6
#  1     4
# -3     3
# -1     3
#  4     3
# -4     2
#  3     2
#  8     2
#  5     1
#  6     1
#  9     1
#  13    1
#  19    1
# Name: error, dtype: int64

# %%
errors_dict = errors["Accuweather"].to_dict()
errors_dict
# Out:
# {0: 8,
#  2: 6,
#  1: 4,
#  -3: 3,
#  -1: 3,
#  4: 3,
#  -4: 2,
#  3: 2,
#  8: 2,
#  5: 1,
#  6: 1,
#  9: 1,
#  13: 1,
#  19: 1}

# %% [markdown]
# ## Mean
#
# Okay I want to see what the mean looks like as well

# %%
means = df_chi.groupby("forecast_date")[["forecast_temperature", "observed_temperature"]].mean()
means
# Out:
#                forecast_temperature  observed_temperature
# forecast_date
# 2022-10-15                54.500000                  55.0
# 2022-10-16                55.750000                  57.0
# 2022-10-17                42.000000                  45.0
# 2022-10-18                46.500000                  50.0
# 2022-10-23                78.250000                  81.0
# 2022-10-24                76.333333                  79.0
# 2022-10-25                64.333333                  71.0
# 2022-10-26                56.500000                  57.0
# 2022-10-27                56.250000                  54.0
# 2022-10-28                60.500000                  61.0
# 2022-10-29                64.500000                  67.0
# 2022-10-30                62.250000                  67.0
# 2022-10-31                60.000000                  61.0
# 2022-11-05                63.750000                  71.0
# 2022-11-06                62.750000                  64.0
# 2022-11-07                54.500000                  58.0
# 2022-11-08                57.500000                  54.0
# 2022-11-09                68.750000                  70.0
# 2022-11-10                73.750000                  76.0
# 2022-11-12                39.000000                  48.0
# 2022-11-13                40.000000                  53.0
# 2022-11-14                42.500000                  51.0
# 2022-11-15                38.750000                  37.0
# 2022-11-16                37.250000                  35.0
# 2022-11-17                33.750000                  34.0
# 2022-11-19                27.750000                  27.0
# 2022-11-21                43.500000                  47.0
# 2022-11-22                48.750000                  52.0
# 2022-11-23                55.750000                  59.0
# 2022-11-25                51.750000                  52.0
# 2022-11-27                44.250000                  46.0
# 2022-11-29                58.000000                  59.0
# 2022-12-02                50.500000                  52.0
# 2022-12-03                36.250000                  52.0
# 2022-12-04                39.500000                  40.0
# 2022-12-05                44.000000                  44.0
# 2022-12-06                45.000000                  44.0
# 2022-12-07                45.250000                  43.0

# %%
means["f_t_round"] = means["forecast_temperature"].round().astype(int)
means["error"] = means["observed_temperature"] - means["f_t_round"]

# %%
means["error"].mean()
# Out:
# 2.5

# %%
means["error"].abs().mean()
# Out:
# 3.236842105263158

# %% [markdown]
# ### Metrics
#
# Okay so I guess we want to get the mean and stdev?

# %%
df_chi_accu = df_chi[df_chi["PLATFORM"] == "Accuweather"]
df_chi_accu
# Out:
#     CITY forecast_date     PLATFORM  forecast_temperature observed_date  \
# 3    CHI    2022-11-05  Accuweather                    63    2022-11-05
# 11   CHI    2022-11-06  Accuweather                    63    2022-11-06
# 19   CHI    2022-11-07  Accuweather                    56    2022-11-07
# 27   CHI    2022-11-08  Accuweather                    58    2022-11-08
# 35   CHI    2022-11-09  Accuweather                    68    2022-11-09
# 124  CHI    2022-10-31  Accuweather                    61    2022-10-31
# 128  CHI    2022-10-30  Accuweather                    63    2022-10-30
# 132  CHI    2022-10-29  Accuweather                    65    2022-10-29
# 136  CHI    2022-10-28  Accuweather                    61    2022-10-28
# 140  CHI    2022-10-27  Accuweather                    58    2022-10-27
# 144  CHI    2022-10-26  Accuweather                    57    2022-10-26
# 148  CHI    2022-10-15  Accuweather                    54    2022-10-15
# 154  CHI    2022-10-16  Accuweather                    57    2022-10-16
# 156  CHI    2022-10-17  Accuweather                    42    2022-10-17
# 160  CHI    2022-10-18  Accuweather                    45    2022-10-18
# 164  CHI    2022-10-23  Accuweather                    77    2022-10-23
# 168  CHI    2022-10-24  Accuweather                    76    2022-10-24
# 171  CHI    2022-10-25  Accuweather                    65    2022-10-25
# 176  CHI    2022-11-10  Accuweather                    74    2022-11-10
# 184  CHI    2022-11-12  Accuweather                    39    2022-11-12
# 192  CHI    2022-11-13  Accuweather                    40    2022-11-13
# 200  CHI    2022-11-14  Accuweather                    43    2022-11-14
# 208  CHI    2022-11-15  Accuweather                    40    2022-11-15
# 216  CHI    2022-11-16  Accuweather                    38    2022-11-16
# 224  CHI    2022-11-17  Accuweather                    34    2022-11-17
# 232  CHI    2022-11-19  Accuweather                    28    2022-11-19
# 240  CHI    2022-11-21  Accuweather                    45    2022-11-21
# 248  CHI    2022-11-22  Accuweather                    50    2022-11-22
# 256  CHI    2022-11-23  Accuweather                    55    2022-11-23
# 264  CHI    2022-11-25  Accuweather                    52    2022-11-25
# 272  CHI    2022-11-27  Accuweather                    45    2022-11-27
# 280  CHI    2022-11-29  Accuweather                    58    2022-11-29
# 288  CHI    2022-12-02  Accuweather                    52    2022-12-02
# 296  CHI    2022-12-03  Accuweather                    33    2022-12-03
# 304  CHI    2022-12-04  Accuweather                    41    2022-12-04
# 312  CHI    2022-12-05  Accuweather                    44    2022-12-05
# 320  CHI    2022-12-06  Accuweather                    45    2022-12-06
# 328  CHI    2022-12-07  Accuweather                    46    2022-12-07
#
#      observed_temperature  error
# 3                      71      8
# 11                     64      1
# 19                     58      2
# 27                     54     -4
# 35                     70      2
# 124                    61      0
# 128                    67      4
# 132                    67      2
# 136                    61      0
# 140                    54     -4
# 144                    57      0
# 148                    55      1
# 154                    57      0
# 156                    45      3
# 160                    50      5
# 164                    81      4
# 168                    79      3
# 171                    71      6
# 176                    76      2
# 184                    48      9
# 192                    53     13
# 200                    51      8
# 208                    37     -3
# 216                    35     -3
# 224                    34      0
# 232                    27     -1
# 240                    47      2
# 248                    52      2
# 256                    59      4
# 264                    52      0
# 272                    46      1
# 280                    59      1
# 288                    52      0
# 296                    52     19
# 304                    40     -1
# 312                    44      0
# 320                    44     -1
# 328                    43     -3

# %%
df_chi_accu["error"].mean()
df_chi_accu["error"].abs().mean()
# Out:
# 3.210526315789474

# %%
def metrics(df, platform, city):
    df = df.copy()
    
    df = df[df["CITY"]== city]
    df = df[df["PLATFORM"] == platform]
    
    mean = df["error"].mean()
    abs_mean = df["error"].abs().mean()
    
    print(f'Mean Error for {platform} in {city}: {mean}')
    print(f'Mean Absolute Error for {platform} in {city}: {abs_mean}')
    
metrics(df, "foreca", "CHI")
# Out:
# Mean Error for foreca in CHI: 2.3055555555555554
# Mean Absolute Error for foreca in CHI: 2.9722222222222223

# %%
for city in set(df["CITY"]):
    
    for platform in set(df["PLATFORM"]):
        
        metrics(df, platform, city)
        print("\n")
# Out:
# Mean Error for NWS in CHI: 3.4473684210526314
# Mean Absolute Error for NWS in CHI: 3.8684210526315788
#
#
# Mean Error for foreca in CHI: 2.3055555555555554
# Mean Absolute Error for foreca in CHI: 2.9722222222222223
#
#
# Mean Error for TWC in CHI: 1.736842105263158
# Mean Absolute Error for TWC in CHI: 2.789473684210526
#
#
# Mean Error for Accuweather in CHI: 2.1578947368421053
# Mean Absolute Error for Accuweather in CHI: 3.210526315789474
#
#
# Mean Error for NWS in NYC: 0.6842105263157895
# Mean Absolute Error for NWS in NYC: 2.1052631578947367
#
#
# Mean Error for foreca in NYC: 1.2972972972972974
# Mean Absolute Error for foreca in NYC: 2.2162162162162162
#
#
# Mean Error for TWC in NYC: 0.9473684210526315
# Mean Absolute Error for TWC in NYC: 1.631578947368421
#
#
# Mean Error for Accuweather in NYC: 0.15789473684210525
# Mean Absolute Error for Accuweather in NYC: 1.7894736842105263

# %% [markdown]
# ### Get Odds
#
# Okay this is going to be super crazy but whatever
#
# Heres' a good start: https://stackoverflow.com/questions/38711541/how-to-compute-the-probability-of-a-value-given-a-list-of-samples-from-a-distrib

# %%
def odds(df, platform, city):
    df = df.copy()
    df = df[df["CITY"]== city]
    df = df[df["PLATFORM"] == platform]
    
    counts = df["error"].value_counts()
    total = counts.sum()
    
    
    
    return counts / total

error_odds = odds(df, "foreca", "CHI")
error_odds
# Out:
#  0     0.222222
#  4     0.138889
#  2     0.138889
#  3     0.111111
# -3     0.083333
# -1     0.083333
#  5     0.055556
#  1     0.055556
#  8     0.027778
#  9     0.027778
#  14    0.027778
#  10    0.027778
# Name: error, dtype: float64

# %% [markdown]
# ### And now given that table
#
# We want to be able to say, what is the probability of it being 71 deg when the forecast is 72.

# %%
def probability_blaster(forecast, threshold, operator, odds):
    diff = forecast - threshold
    
    if operator == "lt":
        new_odds = odds[odds.keys() < diff]
    
    return new_odds.sum()
    
probability_blaster(71, 72, "lt", error_odds)
# Out:
# 0.08333333333333333

# %% [markdown]
# ### Here is the next step!!!!
#
# So let's say you wanted to have an ensemble. You can't just get the probabilities from each of them. Just think bout it it now that you have this.
#
# So what you have to do is get the numbers and the counts for each platform and then go from there.
#
# NOW! this only matters if it's a different number of observations. This is worth investigating.
#
# df_chi[["PLATFORM", "error"]].groupby('PLATFORM')["error"].value_counts()

# %%
df[df["CITY"] == "CHI"]
# Out:
#     CITY forecast_date     PLATFORM  forecast_temperature observed_date  \
# 0    CHI    2022-11-05          TWC                    65    2022-11-05
# 3    CHI    2022-11-05  Accuweather                    63    2022-11-05
# 5    CHI    2022-11-05          NWS                    61    2022-11-05
# 7    CHI    2022-11-05       foreca                    66    2022-11-05
# 8    CHI    2022-11-06          TWC                    64    2022-11-06
# ..   ...           ...          ...                   ...           ...
# 324  CHI    2022-12-06       foreca                    45    2022-12-06
# 325  CHI    2022-12-07          TWC                    44    2022-12-07
# 328  CHI    2022-12-07  Accuweather                    46    2022-12-07
# 330  CHI    2022-12-07          NWS                    45    2022-12-07
# 332  CHI    2022-12-07       foreca                    46    2022-12-07
#
#      observed_temperature  error
# 0                      71      6
# 3                      71      8
# 5                      71     10
# 7                      71      5
# 8                      64      0
# ..                    ...    ...
# 324                    44     -1
# 325                    43     -1
# 328                    43     -3
# 330                    43     -2
# 332                    43     -3
#
# [150 rows x 7 columns]

# %%
def error_counts(df, city):
    df = df[df["CITY"] == city].copy()
    value_counts = df[["PLATFORM", "error"]].groupby('PLATFORM')["error"].value_counts().rename("error_count")
    value_counts = value_counts.to_frame()
    value_counts = value_counts.reset_index(level='error')
    
    return value_counts

df_co = error_counts(df, "CHI")
df_co
# Out:
#              error  error_count
# PLATFORM
# Accuweather      0            8
# Accuweather      2            6
# Accuweather      1            4
# Accuweather     -3            3
# Accuweather     -1            3
# Accuweather      4            3
# Accuweather     -4            2
# Accuweather      3            2
# Accuweather      8            2
# Accuweather      5            1
# Accuweather      6            1
# Accuweather      9            1
# Accuweather     13            1
# Accuweather     19            1
# NWS              4            7
# NWS              3            6
# NWS              1            5
# NWS              0            4
# NWS             -2            3
# NWS              2            3
# NWS             -1            2
# NWS              5            2
# NWS              9            2
# NWS             10            2
# NWS             13            1
# NWS             21            1
# TWC              1            8
# TWC              0            7
# TWC             -1            5
# TWC              2            3
# TWC              3            3
# TWC             -3            2
# TWC             -2            2
# TWC             -5            1
# TWC              4            1
# TWC              5            1
# TWC              6            1
# TWC              7            1
# TWC              8            1
# TWC             12            1
# TWC             21            1
# foreca           0            8
# foreca           2            5
# foreca           4            5
# foreca           3            4
# foreca          -3            3
# foreca          -1            3
# foreca           1            2
# foreca           5            2
# foreca           8            1
# foreca           9            1
# foreca          10            1
# foreca          14            1

# %%
def error_samples(df, city):
    df = df[df["CITY"] == city].copy()
    counts = df[["PLATFORM", "error"]].groupby("PLATFORM").count()
    counts.columns=["samples"]
    
    return counts

error_samples(df, "CHI")
# Out:
#              samples
# PLATFORM
# Accuweather       38
# NWS               38
# TWC               38
# foreca            36

# %% [markdown]
# error = df["observed_temperature"] -  df["forecast_temperature"]

# %%
def combined_odds(df, city, forecast, operator, threshold):
    
    errors = error_counts(df, city)
    error_to_predict = threshold - forecast
    
    # trim the erros based on the operator
    if operator == "lt=":
        errors = errors[errors["error"] <= error_to_predict]
    
    summed_errors = errors.groupby("PLATFORM")["error_count"].sum().to_frame()
    
    samples = error_samples(df, city)
    
    fin = samples.join(summed_errors).fillna(0)
    
    total_errors = fin["error_count"].sum()
    total_samples = fin["samples"].sum()
    
    probability = total_errors / total_samples
    
    fin["probability"] = fin["error_count"] / fin["samples"]
    
    return fin, probability

k = combined_odds(df, "CHI", 75, "lt=", 71)
k
# Out:
# (             samples  error_count  probability
#  PLATFORM
#  Accuweather       38          2.0     0.052632
#  NWS               38          0.0     0.000000
#  TWC               38          1.0     0.026316
#  foreca            36          0.0     0.000000,
#  0.02)

# %% [markdown]
# ## Except that's not it, is it
#
# Now we have to
#
# 1) Get the forecast for each platoform
#
# 2) Trim each one based on that
#
# 3) THEN do what we've done above

# %%
query = """SELECT * FROM forecasts
    WHERE date(FORECAST_DATE) =
        (SELECT date(FORECAST_DATE) FROM forecasts
        ORDER BY date(FORECAST_DATE) desc
        LIMIT 1);"""

# %%
conn = sqlite3.connect(str(db_path))

# %%
df_f = pd.read_sql_query(query, conn)
conn.close()
df_f
# Out:
#      ID CITY               FORECAST_DATE            TIME_OF_FORECAST  \
# 0  None  CHI  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 1  None  NYC  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 2  None  NYC  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 3  None  CHI  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 4  None  NYC  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 5  None  CHI  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 6  None  NYC  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 7  None  CHI  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
#
#       PLATFORM  TEMPERATURE
# 0          TWC           40
# 1          TWC           44
# 2  Accuweather           47
# 3  Accuweather           40
# 4          NWS           46
# 5          NWS           39
# 6       foreca           46
# 7       foreca           39

# %%
(df_f["CITY"] == "CHI") & (df_f["PLATFORM"] == "TWC")
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %% [markdown]
#     if operator == "lt=":
#         errors = errors[errors["error"] <= error_to_predict]

# %%
def city_platform(df, city, platform):
    
    df = df.copy()
    mask = (df["CITY"] == city) & (df["PLATFORM"] == platform)
    
    return df[mask]

# %%
def trim_errors(df, error, operator):
    df = df.copy()
    
    if operator == "lt=":
        df = df[df["error"] <= error]
    elif operator == "gt=":
        df = df[df["error"] >= error]
    elif operator == "bw":
        mask = (df["error"] >= error[0]) & (df["error"] <= error[1])
        df = df[mask]
        
    return df

# %%
def errors_by_platform(df, city, platform, forecast, threshold, operator):
    
    if isinstance(threshold, type(int())):
        error = threshold - forecast
    elif isinstance(threshold, type(tuple())):
        error = (threshold[0] - forecast, threshold[1] - forecast)
    
    k = city_platform(df, city, platform)
    samples = len(k)

    
    k = trim_errors(k, error, operator)
    
    errors = len(k)
    
    return errors, samples
    

errors_by_platform(df, "CHI", "TWC", 40, (38, 39), "bw")
# Out:
# (7, 38)

# %%
errors_by_platform(df, "CHI", "TWC", 40, 37, "lt=")
# Out:
# (3, 38)

# %%
errors_by_platform(df, "CHI", "TWC", 40, 40, "gt=")
# Out:
# (28, 38)

# %%
def city_odds(df, city, forecast, threshold, operator):
    
    # get a list of all unique platforms
    platforms = list(df[df["CITY"] == city]["PLATFORM"].unique())
    
    errors_dict = dict()
    
    for platform in platforms:
        t = errors_by_platform(df, city, platform, forecast, threshold, operator)
        errors_dict[platform] = t
    
    return errors_dict

    
errors = city_odds(df, "CHI", 40, 38, "lt=")

# %%
df_e = pd.DataFrame.from_dict(errors, orient='index', columns=["errors", "samples"])
df_e
# Out:
#              errors  samples
# TWC               5       38
# Accuweather       5       38
# NWS               3       38
# foreca            3       36

# %%
to_add = {"errors":df_e["errors"].sum(), "samples":df_e["samples"].sum()}
df_e = df_e.append(pd.Series(to_add, name="Total"), ignore_index=False)

# %%
df_e["probability"] = df_e["errors"] / df_e["samples"]
df_e
# Out:
#              errors  samples  probability
# TWC               5       38     0.131579
# Accuweather       5       38     0.131579
# NWS               3       38     0.078947
# foreca            3       36     0.083333
# Total            16      150     0.106667

# %% [markdown]
# ## Okay next steps
#
# Okay now you need to get the df_f and then go through each forecast. In addition, you need to be able to do something 'between' something.

# %%
def errors_by_city(df_f, df, city, threshold, operator):
    
    df_f = df_f[df_f["CITY"] == city].copy()
    
    errors_dict = dict()
    
    for row in df_f.itertuples():
        
        # get each platform and forecast
        t = errors_by_platform(df, city, row[5], row[6], threshold, operator)
        errors_dict[row[5]] = t
    return errors_dict

errors_by_city(df_f, df, "CHI", 51, "lt=")
# Out:
# {'TWC': (36, 38), 'Accuweather': (36, 38), 'NWS': (36, 38), 'foreca': (35, 36)}

# %%
def odds_by_city(df_f, df, city, threshold, operator):
    
    errors = errors_by_city(df_f, df, city, threshold, operator)
    df_e = pd.DataFrame.from_dict(errors, orient='index', columns=["errors", "samples"])
    
    to_add = {"errors":df_e["errors"].sum(), "samples":df_e["samples"].sum()}
    df_e = df_e.append(pd.Series(to_add, name="Total"), ignore_index=False)
    
    df_e["probability"] = df_e["errors"] / df_e["samples"]
    
    return df_e
    
    
    
odds_by_city(df_f, df, "CHI", 47, "lt=")
# Out:
#              errors  samples  probability
# TWC              35       38     0.921053
# Accuweather      33       38     0.868421
# NWS              32       38     0.842105
# foreca           33       36     0.916667
# Total           133      150     0.886667

# %%
odds_by_city(df_f, df, "CHI", (34, 35), "bw")
# Out:
#              errors  samples  probability
# TWC               1       38     0.026316
# Accuweather       0       38     0.000000
# NWS               0       38     0.000000
# foreca            0       36     0.000000
# Total             1      150     0.006667

# %%
df_f
# Out:
#      ID CITY               FORECAST_DATE            TIME_OF_FORECAST  \
# 0  None  CHI  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 1  None  NYC  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 2  None  NYC  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 3  None  CHI  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 4  None  NYC  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 5  None  CHI  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 6  None  NYC  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
# 7  None  CHI  2022-12-09 21:32:24.496395  2022-12-08 21:32:24.496391
#
#       PLATFORM  TEMPERATURE
# 0          TWC           40
# 1          TWC           44
# 2  Accuweather           47
# 3  Accuweather           40
# 4          NWS           46
# 5          NWS           39
# 6       foreca           46
# 7       foreca           39

# %% [markdown]
# ## OKay let's put it all together

# %%
boop = sc.scrape_websites()
boop
# Out:
# TWCCHI
# should already be fahrenheit
# TWCCHI
# TWCNYC
# AccuweatherNYC
# AccuweatherCHI
# AccuweatherCHI
# NWSNYC
# NWSCHI
# forecaNYC
# forecaCHI
# [['CHI',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'TWC',
#   '43'],
#  ['NYC',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'TWC',
#   '40'],
#  ['NYC',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'Accuweather',
#   '43'],
#  ['CHI',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'Accuweather',
#   '43'],
#  ['NYC',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'NWS',
#   '41'],
#  ['CHI',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'NWS',
#   '40'],
#  ['NYC',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'foreca',
#   '39'],
#  ['CHI',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'foreca',
#   '43']]

# %%
def forecasts():
    # change
    conn = sqlite3.connect(str(db_path))
    
    query = """SELECT forecasts.CITY, 
        date(FORECAST_DATE) as forecast_date, 
        PLATFORM, 
        forecasts.TEMPERATURE as forecast_temperature,
        date(DATE) as observed_date,
        observed_temp.TEMPERATURE as observed_temperature
         FROM forecasts
        LEFT JOIN observed_temp
        ON forecasts.city = observed_temp.city
        AND date(forecasts.forecast_date) = date(observed_temp.date);
        """
    df = pd.read_sql_query(query, conn)
    conn.close()
    df = df.dropna(subset=['observed_temperature', "forecast_temperature"])
    df["observed_temperature"] = df["observed_temperature"].astype(int)
    df["forecast_temperature"] = df["forecast_temperature"].astype(int)
    df["error"] = df["observed_temperature"] -  df["forecast_temperature"] 
    return df
df = forecasts()
df
# Out:
#     CITY forecast_date     PLATFORM  forecast_temperature observed_date  \
# 0    CHI    2022-11-05          TWC                    65    2022-11-05
# 1    NYC    2022-11-05          TWC                    73    2022-11-05
# 2    NYC    2022-11-05  Accuweather                    73    2022-11-05
# 3    CHI    2022-11-05  Accuweather                    63    2022-11-05
# 4    NYC    2022-11-05          NWS                    72    2022-11-05
# ..   ...           ...          ...                   ...           ...
# 328  CHI    2022-12-07  Accuweather                    46    2022-12-07
# 329  NYC    2022-12-07          NWS                    57    2022-12-07
# 330  CHI    2022-12-07          NWS                    45    2022-12-07
# 331  NYC    2022-12-07       foreca                    57    2022-12-07
# 332  CHI    2022-12-07       foreca                    46    2022-12-07
#
#      observed_temperature  error
# 0                      71      6
# 1                      76      3
# 2                      76      3
# 3                      71      8
# 4                      76      4
# ..                    ...    ...
# 328                    43     -3
# 329                    59      2
# 330                    43     -2
# 331                    59      2
# 332                    43     -3
#
# [301 rows x 7 columns]

# %%
def list_to_dataframe(forecast_list):
    
    df = pd.DataFrame(forecast_list, columns=["CITY", "FORECAST_DATE", "TIME_OF_FORECAST", "PLATFORM", "TEMPERATURE"])
    df["ID"] = None
    df = df[["ID", "CITY", "FORECAST_DATE", "TIME_OF_FORECAST", "PLATFORM", "TEMPERATURE"]]
    df["TEMPERATURE"] = df["TEMPERATURE"].astype(int)
    return df

list_to_dataframe(boop)
# Out:
#      ID CITY               FORECAST_DATE            TIME_OF_FORECAST  \
# 0  None  CHI  2022-12-10 21:37:30.405755  2022-12-09 21:37:30.405750
# 1  None  NYC  2022-12-10 21:37:30.405755  2022-12-09 21:37:30.405750
# 2  None  NYC  2022-12-10 21:37:30.405755  2022-12-09 21:37:30.405750
# 3  None  CHI  2022-12-10 21:37:30.405755  2022-12-09 21:37:30.405750
# 4  None  NYC  2022-12-10 21:37:30.405755  2022-12-09 21:37:30.405750
# 5  None  CHI  2022-12-10 21:37:30.405755  2022-12-09 21:37:30.405750
# 6  None  NYC  2022-12-10 21:37:30.405755  2022-12-09 21:37:30.405750
# 7  None  CHI  2022-12-10 21:37:30.405755  2022-12-09 21:37:30.405750
#
#       PLATFORM  TEMPERATURE
# 0          TWC           43
# 1          TWC           40
# 2  Accuweather           43
# 3  Accuweather           43
# 4          NWS           41
# 5          NWS           40
# 6       foreca           39
# 7       foreca           43

# %% [markdown]
# ## Okay this is super janky
#
# But here's an example of what a read-in yaml is going to look like:

# %%
handles = {"CHI":
    {
        "lt=":42,
        "bw":[(43,44), (45,46)],
        "gt=":47
    },
 "NYC":
    {
        "lt=":40,
        "bw":[(41,42), (43,44)],
        "gt=":45
    }
}
handles
# Out:
# {'CHI': {'lt=': 42, 'bw': [(43, 44), (45, 46)], 'gt=': 47},
#  'NYC': {'lt=': 40, 'bw': [(41, 42), (43, 44)], 'gt=': 45}}

# %%
def key_gen(city, operator, threshold):
    
    return f"{city} - {operator} - {threshold}"

# %%
# odds_by_city(df_f, df, "CHI", (34, 35), "bw")



def odds(forecast_list, handles):
    
    odds_dict = dict()

    df = forecasts()
    df_f = list_to_dataframe(forecast_list)
    
    for city in handles:
        for operator in handles[city]:
            if operator == "bw":
                for pair in handles[city][operator]:
                    
                    k = odds_by_city(df_f, df, city, pair, operator)
                    
                    key = key_gen(city, operator, pair)
                    
                    odds_dict[key] = k
            else:
                threshold = handles[city][operator]
                k = odds_by_city(df_f, df, city, threshold, operator)
                key = key_gen(city, operator, threshold)
                odds_dict[key] = k
                    
    return odds_dict

    
ret = odds(boop, handles)

# %%
boop
# Out:
# [['CHI',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'TWC',
#   '43'],
#  ['NYC',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'TWC',
#   '40'],
#  ['NYC',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'Accuweather',
#   '43'],
#  ['CHI',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'Accuweather',
#   '43'],
#  ['NYC',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'NWS',
#   '41'],
#  ['CHI',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'NWS',
#   '40'],
#  ['NYC',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'foreca',
#   '39'],
#  ['CHI',
#   '2022-12-10 21:37:30.405755',
#   '2022-12-09 21:37:30.405750',
#   'foreca',
#   '43']]

# %%
for i in ret:
    print(i)
    print(ret[i])
    print()
# Out:
# CHI - lt= - 42
#              errors  samples  probability
# TWC              10       38     0.263158
# Accuweather       8       38     0.210526
# NWS              17       38     0.447368
# foreca            6       36     0.166667
# Total            41      150     0.273333
#
# CHI - bw - (43, 44)
#              errors  samples  probability
# TWC              15       38     0.394737
# Accuweather      12       38     0.315789
# NWS              13       38     0.342105
# foreca           10       36     0.277778
# Total            50      150     0.333333
#
# CHI - bw - (45, 46)
#              errors  samples  probability
# TWC               6       38     0.157895
# Accuweather       8       38     0.210526
# NWS               2       38     0.052632
# foreca            9       36     0.250000
# Total            25      150     0.166667
#
# CHI - gt= - 47
#              errors  samples  probability
# TWC               7       38     0.184211
# Accuweather      10       38     0.263158
# NWS               6       38     0.157895
# foreca           11       36     0.305556
# Total            34      150     0.226667
#
# NYC - lt= - 40
#              errors  samples  probability
# TWC              16       38     0.421053
# Accuweather       4       38     0.105263
# NWS              12       38     0.315789
# foreca           16       37     0.432432
# Total            48      151     0.317881
#
# NYC - bw - (41, 42)
#              errors  samples  probability
# TWC              17       38     0.447368
# Accuweather      11       38     0.289474
# NWS              13       38     0.342105
# foreca           15       37     0.405405
# Total            56      151     0.370861
#
# NYC - bw - (43, 44)
#              errors  samples  probability
# TWC               3       38     0.078947
# Accuweather      17       38     0.447368
# NWS               8       38     0.210526
# foreca            6       37     0.162162
# Total            34      151     0.225166
#
# NYC - gt= - 45
#              errors  samples  probability
# TWC               2       38     0.052632
# Accuweather       6       38     0.157895
# NWS               5       38     0.131579
# foreca            0       37     0.000000
# Total            13      151     0.086093

# %% [markdown]
# ### TODO:
#
#     you need to finish the module: `/src/analytics.py`
#     you need to make a reader for the yaml file

# %%
import src.analytics as al

# %%
al.odds(boop, handles)
# Out:
# {'CHI - lt= - 42':              errors  samples  probability
#  TWC              10       38     0.263158
#  Accuweather       8       38     0.210526
#  NWS              17       38     0.447368
#  foreca            6       36     0.166667
#  Total            41      150     0.273333,
#  'CHI - bw - (43, 44)':              errors  samples  probability
#  TWC              15       38     0.394737
#  Accuweather      12       38     0.315789
#  NWS              13       38     0.342105
#  foreca           10       36     0.277778
#  Total            50      150     0.333333,
#  'CHI - bw - (45, 46)':              errors  samples  probability
#  TWC               6       38     0.157895
#  Accuweather       8       38     0.210526
#  NWS               2       38     0.052632
#  foreca            9       36     0.250000
#  Total            25      150     0.166667,
#  'CHI - gt= - 47':              errors  samples  probability
#  TWC               7       38     0.184211
#  Accuweather      10       38     0.263158
#  NWS               6       38     0.157895
#  foreca           11       36     0.305556
#  Total            34      150     0.226667,
#  'NYC - lt= - 40':              errors  samples  probability
#  TWC              16       38     0.421053
#  Accuweather       4       38     0.105263
#  NWS              12       38     0.315789
#  foreca           16       37     0.432432
#  Total            48      151     0.317881,
#  'NYC - bw - (41, 42)':              errors  samples  probability
#  TWC              17       38     0.447368
#  Accuweather      11       38     0.289474
#  NWS              13       38     0.342105
#  foreca           15       37     0.405405
#  Total            56      151     0.370861,
#  'NYC - bw - (43, 44)':              errors  samples  probability
#  TWC               3       38     0.078947
#  Accuweather      17       38     0.447368
#  NWS               8       38     0.210526
#  foreca            6       37     0.162162
#  Total            34      151     0.225166,
#  'NYC - gt= - 45':              errors  samples  probability
#  TWC               2       38     0.052632
#  Accuweather       6       38     0.157895
#  NWS               5       38     0.131579
#  foreca            0       37     0.000000
#  Total            13      151     0.086093}
